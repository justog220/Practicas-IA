# %% [markdown]
# # <span style="color:RoyalBlue">Visualización de Datos</span>

# %% [markdown]
# Python cuanta con un rico conjunto de bibliotecas para la visualización gráfica y científica.
#
# En esta materia esa capacidad es de gran utilidad tanto en la fase de comprensión de datos (particularmente para realizar un análisis exploratorio de datos), para comprender el proceso de construcción de modelos de minería de datos como para la presentación de resultados.
#
# En todo momento es útil tener presente qué característica de los datos se desea resaltar. No se trata de crear un *collage* de datos sino de **transmitir una idea** o un resultado de forma visual para que sea fácilmente interpretable.
#
# Algunas de las bibliotecas de visualización más usadas son:
#
# *   **Matplotlib**
# *   **Seaborn**
# *   **ggplot**
# *   **Plotly**
#
# Nos focalizaremos en el uso de **Maplotlib** y **SeaBorn**.
#
#
# Se puede indagar más sobre ellas [aqui](https://www.fusioncharts.com/blog/best-python-data-visualization-libraries/).

# %% [markdown]
# ## <span style="color:CornflowerBlue">MatPlotLib</span>

# %% [markdown]
# [Matplotlib](https://matplotlib.org/) (**Mat**-h **Plot** **Lib**rary) es la libreria estándar de Python para realizar diferentes tipos de gráficos. Tiene una sintaxis similar a las funciones de graficación de Matlab.
#
# <img src="https://matplotlib.org/_static/logo2.png" width= 500>

# %% [markdown]
# Veamos ejemplos simples de graficación con pyplot:

# %%
# Ejemplo 1

import matplotlib.pyplot as plt
# Carga las otras bibliotecas
import numpy as np

# Prepara la biblioteca para incrustar las gráficas en el documento (sinó hay que llamar a plt.show())
# %matplotlib inline

# Generar los datos
x = np.linspace(0,10,1000)
y = np.square(x)

# %%
# Graficar y colocar título y etiqueta en los ejes
plt.plot(x,y)
plt.title("Función Cuadrática")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Configuración de gráficos

# %% [markdown]
# Veamos un segundo ejemplo con algunos atributos adicionales de los gráficos

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as sc

x = np.arange(0, 2 * sc.pi , 0.25)
plt.plot(x,np.sin(x),'m*', label='Seno')         # punteado magenta con marks de asteriscos
plt.plot(x,np.cos(x),'r--', label='Coseno')      # líneas punteadas rojas
plt.legend()                                     # mostrar las referencias
plt.xlabel('tiempo')
plt.ylabel('amplitud')
plt.title("Función Seno vs. Función Coseno")
# Out:
# Text(0.5, 1.0, 'Función Seno vs. Función Coseno')

# %% [markdown]
# Veamos ahora un ejemplo con paneles múltiples de gráficos

# %%
x = np.arange(0, 2 * sc.pi, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(2, 1, 1)   # 2 filas, 1 columna, posición 1
plt.plot(x, y1, 'b-')  # grafica función y1
plt.xlabel('tiempo')
plt.ylabel('amplitud')

plt.subplot(2, 1, 2)   # 2 filas, 1 columna, posición 2
plt.plot(x, y2, 'r-.') # grafica función y2
plt.xlabel('tiempo')
plt.ylabel('amplitud')

plt.tight_layout()     # Ajustar espaciado entre subplots

print('Ejemplo A:\n')
plt.show()


# Una vez que usamos plt.show() el gráfico se muestra y podemos crear uno nuevo:


plt.subplot(1, 2, 1)   # 1 fila, 2 columnas, posición 1
plt.plot(x, y1, 'b-')  # graficamos función y1
plt.xlabel('tiempo')
plt.ylabel('amplitud')

plt.subplot(1, 2, 2)   # 1 fila, 2 columnas, posición 2
plt.plot(x, y2, 'r-.') # graficamos función y2
plt.xlabel('tiempo')
plt.ylabel('amplitud')

plt.tight_layout()     # Ajustar espaciado entre subplots

print('\n\nEjemplo B:\n')
plt.show()
# Out:
# Ejemplo A:
# Ejemplo B:

# %%
x = np.arange(0, 2* sc.pi, 0.3)
y1 = np.sin(x)
y2 = np.cos(x)

plt.figure(figsize=(12, 4))  # Configuramos el tamaño del gráfico (en pulgadas)

plt.subplot(1, 2, 1)
plt.title("Seno")
plt.plot(x, y1, 'bo')        # Graficamos la función y1
plt.xlabel('Tiempo')
plt.ylabel('Corriente')

plt.subplot(1, 2, 2)
plt.title("Coseno")
plt.plot(x, y2, 'r-.')       # Graficamos la función y2
plt.xlabel('Tiempo')
plt.axis([0, 3, -1, 1])      # Elegimos los límites de los ejes
plt.grid(True)               # Activamos la grilla

plt.show()

# %% [markdown]
# Otros parámetros y configuraciones:
# - `plt.figure( figsize = (w, h) )` seleccionar el tamaño de la figura
# - `plt.subplots(nrows, ncols)` crear un conjunto de subplots para usarlos posteriormente
# - `plt.axis([xmin, xmax, ymin, ymax])` selección de límites de graficación de los ejes
# - `plt.grid()` inserción de una grilla cuadriculada
#
# Se pueden configurar muchísimos más parámetros, que se pueden ver en la documentación de [matplotlib.pyplot](https://matplotlib.org/tutorials/introductory/pyplot.html).

# %% [markdown]
# ### Gráficos de Dispersión *(Scatter Plots)*
#
# Estos gráficos permiten visualizar si existe algún tipo de tendencias o correlaciones entre variables.

# %%
# Ejemplo 1

import numpy as np
import matplotlib.pyplot as plt

N = 50                              # Número de puntos a graficar
x = np.random.rand(N)               # Definición de variables
y = np.random.rand(N)
colors = np.random.rand(N)          # Definición de colores aleatorios
area = 10 

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# En el ejemplo anterior se utilizaron como parámetro de graficación el área de cada punto, el color y su transparencia (*alpha*). Se puede pensar en hacer estas gráficas seleccionando colores diferenntes para cada clase a visualizar.
#
# En el siguiente ejemplo se generan datos correlacionados a partir de variables que tienen una distribución normal.

# %%
# Ejemplo 2

import matplotlib.pyplot as plt
import numpy as np

mu = [0, 0]                          # Valores medios de x e y
cxy = [[1, 1], [1, 2]]               # Matriz de covarianza, [[Cxx, Cxy], [Cyx, Cyy]]
x, y = np.random.multivariate_normal(mu, cxy, 5000).T

plt.scatter(x, y, s=5, alpha=0.5)
plt.show()

# %% [markdown]
# En esa gráfica se puede ver que las variables están correlacionadas (viendo la forma de elipse que se genera en el gráfico). Se puede aumentar o disminuir esas correlaciones modificando la matriz de covarianzas:
# - $C_{ij}$ denota la correlación de $i$ respecto de $j$.
# - $C_{ii}$ denota la autocorrelación de la variable aleatoria $i$, y es semejante a la varianza de $i$.

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Los histogramas son una de las representaciones más usadas para visualizar distribuciones de una variable.
# Para hacer un histograma en matplotlib se usa la función:
#
# > plt.**hist**(x, bins, propiedades)
#
# - **x**: secuencia de datos
# - **bins**: número de separaciones de igual ancho
# - **propiedades**: opcional
#
# Veamos un ejemplo:

# %%
#Ejemplo 1

import matplotlib.pyplot as plt
import numpy as np

rand = np.random.normal(0,2,2000) # Se sintetizan valores aleatorios con distribución normal, media 0 y desvío estandar 2
plt.hist(rand,30)                 # Crea un histograma con 30 bins o rangos
plt.show()

# %% [markdown]
# Se puede usar el parametro densit=True para hacer que se normalice el histograma: la suma de todas las columnas será igual a 1.

# %%
# Ejemplo 2

import matplotlib.pyplot as plt
import numpy as np
mu = 0              # Media de la distribución
sigma = 1           # Desvio estandar
var = sigma**2
t = np.arange(-10,10,0.01)
y = 1/np.sqrt(2*np.pi)*sigma*np.exp(-(t-mu)**2/(2*sigma**2))
rand = np.random.normal(mu,var,10000)
plt.hist(rand,30,density=True, label= "Histograma")
plt.plot(t,y, label= "Función")
plt.legend() 
plt.show()

# %% [markdown]
# ### Gráficos de Caja *(Box Plots)*

# %% [markdown]
# Este tipo de gráficos también llamados *Whisker plot* o gráficos de bigote son otra alternativas para visualizar las distribuciones de los datos bajo estudio.
# La gráfica muestra permite ver algunos indicadores estadísticos de la distribución como es muestra a continuación:
#
#
# <img src="../images/Boxplot.svg.png" width= 600>

# %% [markdown]
# Donde el valor central de la caja marcada con una línea corresponde a la mediana (medida para la cual la mitad de los datos son menores y la otra mitad mayores), el largo de la caja es el rango intercuartil (RIC) que contiene al cincuenta por ciento de los datos, las líneas de punto se llaman vigotes y las líneas en las que finalizan los vigotes son los valores máximos y mínimos si se excluyen los datos atípicos o *outliers*.

# %% [markdown]
# Para hacer un boxplot en matplotlib se usa la función:
#
# > plt.**boxplot**(x, bins, propiedades)
#
# - **x**: secuencia de datos
# - **bins**: número de separaciones de igual ancho
# - **propiedades**: opcional
#
# Veamos un ejemplo:

# %%
# Ejemplo 1
import matplotlib.pyplot as plt
import numpy as np
 
np.random.seed(10)
data = np.random.normal(100, 20, 200) # Valores aleatorios, distribución normal, media 100, desvío estándar 20 
 
fig = plt.figure(figsize =(10, 7))    # Definición del tamaño de canvas de la figura
plt.boxplot(data)                     # Generación de la gráfica
plt.show()

# %% [markdown]
# Estos gráficos son muy útiles para comparar distribuciones entre diferntes conjuntos de datos como se muestra en el siguiente ejemplo:

# %%
# Ejemplo 2

import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)
 
data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]
 
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(data)
ax.set_xticklabels( ["Grupo 1", "Grupo 1", "Grupo 3", "Grupo 4"], rotation=30, fontsize=10)
ax.set_title('Comparación de Distribución entre Grupos', fontsize=14)
ax.set_xlabel('Grupos', fontsize=12)
ax.set_ylabel('Valores', fontsize=12)
 
# show plot
plt.show()

# %% [markdown]
# ### Gráficos de Torta *(Pie Chart)*

# %% [markdown]
# Este tipo de gráficos se usan para mostrar las relaciones entre las partes respecto al todo cuando los datos tienen un número pequeño de divisiones.

# %% [markdown]
# Este gráfico lo realizamos con la siguiente función:
#
#
# > plt.**pie**($tamaños$)

# %%
# Ejemplo 1
import matplotlib.pyplot as plt

sizes = [215, 130, 245, 210, 120, 45]
l = ('P1', 'P2', 'P3', 'P4', 'P5', 'P6') 
plt.pie(sizes, labels=l)
plt.show()

# %% [markdown]
# Este tipo de gráficos también tiene muchos parámetros para configurar su apariencia, por ejemplo cambiar los colores, separar una porción se la torta o insertar los porcentajes en el interior de las porciones:

# %%
import matplotlib.pyplot as plt

l = ('Python', 'C++', 'Ruby', 'Java')
sizes = [255, 130, 245, 210]
c = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue'] # color definido manualmente para cada porción

e = (0.1, 0.2, 0, 0)  # valor de separación de cada porción

fig = plt.figure(figsize =(10, 7))
plt.pie(sizes, explode=e, colors=c, labels=l, autopct='%5.01f%%') # autopct indica agregar el porcentaje y se puede seleccionar el formato de presentación

plt.show()

# %% [markdown]
# ## Guardado de gráficos
#
# Todos los gráficos vistos se pueden guardar como PNG o JPG usando la siguiente función:
#
#     plt.savefig(nombre del archivo)
#
# Es muy imporante que se guarden los gráficos antes del comando plt.show() ya que con ese comando matplotlib envía el gráfico a la pantalla y el canvas de graficación se limpia para hacer otro gráfico.
#
# Se puede especificar la resolución de almacenamiento mediante un valor de puntos por pulgada (*dpi*):
#
#     plt.savefig('plot.png', dpi=500)

# %%
# Ejemplo

import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 7))

# boxplots rectangulares
bplot1 = ax1.boxplot(all_data,
                     vert=True,  # alineación vertical entre cajas
                     patch_artist=True,  # llenar con color
                     labels=labels)
ax1.set_title('BoxPlot Rectangular')

# boxplots con una hendidura
bplot2 = ax2.boxplot(all_data,
                     notch=True,  # usae formato de caja con hendidura (notch)
                     vert=True,
                     patch_artist=True,
                     labels=labels)
ax2.set_title('BoxPlot con Hendidura')

# rellenado de color
colors = ['pink', 'lightblue', 'lightyellow']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# inserción de grilla horizontal
for ax in [ax1, ax2]:
    ax.yaxis.grid(True)
    ax.set_xlabel('Ejemplos')
    ax.set_ylabel('Valores')

# muestro el grafico que prepare
plt.savefig('../images/boxplotsAntes.png', dpi=300)

plt.show()

plt.savefig('../images/boxplotsDespues.png', dpi=300)

# %% [markdown]
# ## <span style="color:CornflowerBlue">Seaborn</span>

# %% [markdown]
# [Seaborn](https://seaborn.pydata.org/) es una biblioteca para visualización de datos basada en matplotlib y que se integra facilmente a las estructuras de Pandas.
#
# <img src="https://seaborn.pydata.org/_static/logo-wide-lightbg.svg" width= 500>

# %% [markdown]
# Seaborn tiene muchas rutinas de graficación propias pero también puede sobreescribir los parámetros por defecto de Matplotlib para mejorar el aspecto gráfico nativo.
# Una vez importado Seaborn se puede setear el estilo llamando al método set():

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

l = ('Python', 'C++', 'Ruby', 'Java')
sizes = [255, 130, 245, 210]
c = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue'] # color definido manualmente para cada porción

e = (0.1, 0.2, 0, 0)  # valor de separación de cada porción

fig = plt.figure(figsize =(10, 7))
plt.pie(sizes, explode=e, colors=c, labels=l, autopct='%5.01f%%') # autopct indica agregar el porcentaje y se puede seleccionar el formato de presentación

plt.show()

# %% [markdown]
# ## Histogramas, KDE y Densidades

# %% [markdown]
# A contiuación veremos cómo se puede graficar dos histogramas correspondientes a variables diferentes para poder compararlos:

# %%
# Ejemplo 1
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# Crea datos
datos = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
datos = pd.DataFrame(data, columns=['x', 'y'])

fig = plt.figure(figsize =(10, 7))

for col in 'xy':
    plt.hist(datos[col], density=True, stacked=True, alpha=0.5)

# %% [markdown]
# Otra opción es suavizar los histogramas para obtener una estimación de las distribuciones usando una estimación de densidad de kernel (KDE) de la siguiente manera:

# %%
fig = plt.figure(figsize =(10, 7))

for col in 'xy':
    sns.kdeplot(datos[col], shade=True)

# %% [markdown]
# Y ambos se pueden combinar eun un displot:

# %%
sns.displot(datos['x'], kde=True)
sns.displot(datos['y'], kde=True)

# %% [markdown]
# Si se pasan dataset 2D al kdeplot, se pueden obterner cortes seccionales de la distribución conjunta:

# %%
sns.kdeplot(data=datos,x='x',y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# A ese gráfico se puede sumar la distribución conjunta y marginales:

# %%
with sns.axes_style('white'):
    sns.jointplot(x="x", y="y", data=datos, kind='kde');

# %% [markdown]
# ## Gráfico Categórico *(Cat Plot)*
# Este tipo de gráficos puede resultar útil para comparar la distribución de un parámetro para diferentes clases.

# %%
import seaborn as sns

sns.set_theme(style="ticks")
ejercicios = sns.load_dataset("exercise")
ejercicios.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %% [markdown]
# También se puede utilizar un tipo diferente de gráfico para la misma visualización:

# %%
g = sns.catplot(x="time", y="pulse", hue="kind", data=exercise, kind="box")

# %% [markdown]
# O se puede optar por la visualización horizontal:

# %%
g = sns.catplot(x="pulse", y="diet",
                hue="time", row="kind",
                data=ejercicios,
                orient="h", height=4, aspect=3, palette="Set3",
                kind="violin", dodge=True, cut=0, bw=.2)

# %% [markdown]
# ## Gráfico de a Pares *(Pair Plots)*
# Es un tipo de gráfico que permite analizar el comportamiento entre pares de variables.
# Tiene una forma de matriz en la que la diagonal presenta el histograma de la variable correspondiente y en las demás celdas gráficos de dispersión entre un par de variables diferentes.

# %%
# Ejemplo 1
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.pairplot(penguins, hue='sex', height=3)  #Muestra el gráfico de pares para cada variable usando el sexo como variable de contraste"""
